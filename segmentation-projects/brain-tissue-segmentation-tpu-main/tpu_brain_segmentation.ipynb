# %% [markdown]
# This data was obtained from MR images ,then annotated and augmented. Binary masks contain only brain tissue, excluding the tumor tissue.
#
#
# I have used the following methods.
# - Unet architecture with elu activation function,
# - Dice coefficient implementation,
# - The project took place using Google TPU

# %%
# !pip install visualkeras
# Out:
# Requirement already satisfied: visualkeras in /usr/local/lib/python3.10/dist-packages (0.0.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.23.5)
# Requirement already satisfied: aggdraw>=1.3.11 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.3.16)

# %%
# Importing dependencies

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import visualkeras

import tensorflow as tf
from tensorflow import keras
from keras import backend as K
from tensorflow.keras.layers import Input, Conv2D,UpSampling2D, Dropout, MaxPooling2D, concatenate, Lambda, BatchNormalization

# %%
# Connecting TPU and creating strategy and the model

tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
strategy = tf.distribute.TPUStrategy(tpu)

# %%
# Loading brain images and correspondent binary masks

X = np.load('/content/drive/MyDrive/Colab Notebooks/X_train_beyin.npy')
y = np.load('/content/drive/MyDrive/Colab Notebooks/Y_train_beyin.npy')
X_t = np.load('/content/drive/MyDrive/Colab Notebooks/X_test.npy')


X_train = X[:,:,:,0]
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1],X_train.shape[2], 1 )


y_train = y[:,:,:,0]
y_train = y_train.reshape(y_train.shape[0],y_train.shape[1],y_train.shape[2], 1 )
y_train = y_train.astype('float32')


X_test = X_t[:,:,:,0]
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],X_test.shape[2], 1 )

# %%
print("train images ", X_train.shape[0])
print("test images ", X_test.shape[0])
# Out:
# train images  4404
# test images  1440

# %%
def create_random_image_and_mask(image, mask,  cmap1 = 'gray', cmap2 = 'gray'):
  idx = random.randint(0, image.shape[0]-1)

  plt.figure(dpi = 150)

  plt.subplot(121)
  plt.imshow(image[idx], cmap =  cmap1)
  plt.title("Original image " + str(idx))

  plt.subplot(122)
  plt.imshow(mask[idx], cmap = cmap2)
  plt.title("Mask")

# %%
create_random_image_and_mask(X_train, y_train)
create_random_image_and_mask(X_train, y_train)
create_random_image_and_mask(X_train, y_train)

# %%
# Creating a convolution block builder

def conv_block(filter_size, kernel_size, padding = 'same', kernel_init = 'he_normal', activation = 'relu'):

  def make(inputs):
    features = Conv2D(filters = filter_size, kernel_size = kernel_size, padding=padding, kernel_initializer = kernel_init, activation = activation )(inputs)
    #features = BatchNormalization()(features)
    #features = Activation(activation)(features)

    features = Conv2D(filters = filter_size, kernel_size = kernel_size, padding=padding, kernel_initializer = kernel_init )(features)
    #features = BatchNormalization()(features)
    #features = Activation(activation)(features)

    return features

  return make

# %%
# Creating Dice metrics

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection+1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)


def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %%
# Creating U-Net model

with strategy.scope():

  inp = Input(shape = (128, 128,1))
  L =  Lambda(lambda x: x / 255.0)(inp)

  C0 = conv_block(32, 3 ,activation = 'elu' )(L)
  M0 = MaxPooling2D(2)(C0)


  C1 = conv_block(64, 3,activation = 'elu'  )(M0)
  M1 = MaxPooling2D(2)(C1)

  C2 = conv_block(128, 3 ,activation = 'elu' )(M1)
  M2 = MaxPooling2D(2)(C2)

  C3 = conv_block(256, 3 ,activation = 'elu' )(M2)
  M3 = MaxPooling2D(2)(C3)

  C4 = conv_block(512, 3 ,activation = 'elu' )(M3)
  D4 = Dropout(0.4)(C4)
  M4 = MaxPooling2D(2)(D4)

  C5 = conv_block(1024, 3 ,activation = 'elu'  )(M4)
  D5 = Dropout(0.4)(C5)

  UP6 = UpSampling2D(size = (2,2))(D5)
  UP6 = Conv2D(512, 2, activation = 'elu', padding = 'same', kernel_initializer = 'lecun_normal')(UP6)
  MERG6 = concatenate([D4, UP6], axis = 3)
  C6 = conv_block(512, 3 )(MERG6)


  UP7 = UpSampling2D(size = (2,2))(C6)
  UP7 = Conv2D(256, 2, activation = 'elu', padding = 'same', kernel_initializer = 'lecun_normal')(UP7)
  MERG7 = concatenate([C3, UP7], axis = 3)
  C7 = conv_block(256, 3)(MERG7)


  UP8 = UpSampling2D(size = (2,2))(C7)
  UP8 = Conv2D(128, 2, activation = 'elu', padding = 'same', kernel_initializer = 'lecun_normal')(UP8)
  MERG8 = concatenate([ C2, UP8], axis = 3)
  C8 = conv_block(128, 3)(MERG8)


  UP9 = UpSampling2D(size = (2,2))(C8)
  UP9 = Conv2D(64, 2, activation = 'elu', padding = 'same', kernel_initializer = 'lecun_normal')(UP9)
  MERG9 = concatenate([ C1, UP9], axis = 3)
  C9 = conv_block(64, 3 )(MERG9)


  UP10 = UpSampling2D(size = (2,2))(C9)
  UP10 = Conv2D(32, 2, activation = 'elu', padding = 'same', kernel_initializer = 'lecun_normal')(UP10)
  MERG10 = concatenate([ C0,UP10 ], axis = 3)
  C10 = conv_block(32, 3 )(MERG10)


  C11 = Conv2D(16, 3, activation = 'elu', padding = 'same', kernel_initializer = 'lecun_normal')(C10)

  out = Conv2D(1, 1, activation = 'sigmoid')(C11)

  model = tf.keras.Model(inputs = inp, outputs = out)

  model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-5) ,  loss = 'binary_crossentropy' , metrics = [dice_coef])
  hist = model.fit(X_train, y_train, validation_split=0.25  , batch_size = 16, epochs = 40 )
# Out:
# Epoch 1/40
# 207/207 [==============================] - 66s 90ms/step - loss: 0.1633 - dice_coef: 0.6444 - val_loss: 0.1163 - val_dice_coef: 0.6788
# Epoch 2/40
# 207/207 [==============================] - 11s 52ms/step - loss: 0.0868 - dice_coef: 0.7748 - val_loss: 0.0921 - val_dice_coef: 0.7516
# Epoch 3/40
# 207/207 [==============================] - 11s 54ms/step - loss: 0.0722 - dice_coef: 0.8137 - val_loss: 0.0784 - val_dice_coef: 0.7871
# Epoch 4/40
# 207/207 [==============================] - 11s 54ms/step - loss: 0.0649 - dice_coef: 0.8342 - val_loss: 0.0687 - val_dice_coef: 0.7877
# Epoch 5/40
# 207/207 [==============================] - 11s 52ms/step - loss: 0.0593 - dice_coef: 0.8495 - val_loss: 0.0643 - val_dice_coef: 0.8212
# Epoch 6/40
# 207/207 [==============================] - 11s 54ms/step - loss: 0.0559 - dice_coef: 0.8588 - val_loss: 0.0649 - val_dice_coef: 0.8159
# Epoch 7/40
# 207/207 [==============================] - 11s 52ms/step - loss: 0.0525 - dice_coef: 0.8676 - val_loss: 0.0634 - val_dice_coef: 0.8249
# Epoch 8/40
# 207/207 [==============================] - 11s 53ms/step - loss: 0.0503 - dice_coef: 0.8736 - val_loss: 0.0575 - val_dice_coef: 0.8363
# Epoch 9/40
# 207/207 [==============================] - 12s 59ms/step - loss: 0.0483 - dice_coef: 0.8783 - val_loss: 0.0573 - val_dice_coef: 0.8358
# Epoch 10/40
# 207/207 [==============================] - 11s 52ms/step - loss: 0.0470 - dice_coef: 0.8815 - val_loss: 0.0562 - val_dice_coef: 0.8384
# Epoch 11/40
# 207/207 [==============================] - 11s 53ms/step - loss: 0.0452 - dice_coef: 0.8860 - val_loss: 0.0580 - val_dice_coef: 0.8408
# Epoch 12/40
# 207/207 [==============================] - 11s 52ms/step - loss: 0.0440 - dice_coef: 0.8892 - val_loss: 0.0551 - val_dice_coef: 0.8450
# Epoch 13/40
# 207/207 [==============================] - 11s 53ms/step - loss: 0.0421 - dice_coef: 0.8939 - val_loss: 0.0552 - val_dice_coef: 0.8503
# Epoch 14/40
# 207/207 [==============================] - 11s 55ms/step - loss: 0.0414 - dice_coef: 0.8967 - val_loss: 0.0545 - val_dice_coef: 0.8570
# Epoch 15/40
# 207/207 [==============================] - 11s 52ms/step - loss: 0.0398 - dice_coef: 0.9005 - val_loss: 0.0534 - val_dice_coef: 0.8597
# Epoch 16/40
# 207/207 [==============================] - 11s 52ms/step - loss: 0.0389 - dice_coef: 0.9023 - val_loss: 0.0556 - val_dice_coef: 0.8480
# Epoch 17/40
# 207/207 [==============================] - 11s 53ms/step - loss: 0.0380 - dice_coef: 0.9044 - val_loss: 0.0545 - val_dice_coef: 0.8609
# Epoch 18/40
# 207/207 [==============================] - 11s 53ms/step - loss: 0.0372 - dice_coef: 0.9069 - val_loss: 0.0555 - val_dice_coef: 0.8613
# Epoch 19/40
# 207/207 [==============================] - 11s 53ms/step - loss: 0.0361 - dice_coef: 0.9095 - val_loss: 0.0530 - val_dice_coef: 0.8617
# Epoch 20/40
# 207/207 [==============================] - 11s 53ms/step - loss: 0.0355 - dice_coef: 0.9117 - val_loss: 0.0534 - val_dice_coef: 0.8684
# Epoch 21/40
# 207/207 [==============================] - 11s 54ms/step - loss: 0.0348 - dice_coef: 0.9139 - val_loss: 0.0522 - val_dice_coef: 0.8673
# Epoch 22/40
# 207/207 [==============================] - 11s 53ms/step - loss: 0.0340 - dice_coef: 0.9156 - val_loss: 0.0528 - val_dice_coef: 0.8694
# Epoch 23/40
# 207/207 [==============================] - 11s 53ms/step - loss: 0.0330 - dice_coef: 0.9182 - val_loss: 0.0551 - val_dice_coef: 0.8676
# Epoch 24/40
# 207/207 [==============================] - 11s 52ms/step - loss: 0.0329 - dice_coef: 0.9186 - val_loss: 0.0538 - val_dice_coef: 0.8719
# Epoch 25/40
# 207/207 [==============================] - 11s 53ms/step - loss: 0.0319 - dice_coef: 0.9210 - val_loss: 0.0541 - val_dice_coef: 0.8758
# Epoch 26/40
# 207/207 [==============================] - 11s 53ms/step - loss: 0.0315 - dice_coef: 0.9219 - val_loss: 0.0537 - val_dice_coef: 0.8759
# Epoch 27/40
# 207/207 [==============================] - 11s 53ms/step - loss: 0.0308 - dice_coef: 0.9235 - val_loss: 0.0546 - val_dice_coef: 0.8747
# Epoch 28/40
# 207/207 [==============================] - 11s 54ms/step - loss: 0.0301 - dice_coef: 0.9257 - val_loss: 0.0557 - val_dice_coef: 0.8778
# Epoch 29/40
# 207/207 [==============================] - 11s 53ms/step - loss: 0.0296 - dice_coef: 0.9268 - val_loss: 0.0537 - val_dice_coef: 0.8790
# Epoch 30/40
# 207/207 [==============================] - 11s 53ms/step - loss: 0.0290 - dice_coef: 0.9284 - val_loss: 0.0548 - val_dice_coef: 0.8755
# Epoch 31/40
# 207/207 [==============================] - 11s 53ms/step - loss: 0.0287 - dice_coef: 0.9292 - val_loss: 0.0553 - val_dice_coef: 0.8769
# Epoch 32/40
# 207/207 [==============================] - 11s 54ms/step - loss: 0.0281 - dice_coef: 0.9302 - val_loss: 0.0524 - val_dice_coef: 0.8844
# Epoch 33/40
# 207/207 [==============================] - 11s 53ms/step - loss: 0.0278 - dice_coef: 0.9314 - val_loss: 0.0548 - val_dice_coef: 0.8811
# Epoch 34/40
# 207/207 [==============================] - 11s 52ms/step - loss: 0.0272 - dice_coef: 0.9328 - val_loss: 0.0570 - val_dice_coef: 0.8816
# Epoch 35/40
# 207/207 [==============================] - 11s 55ms/step - loss: 0.0269 - dice_coef: 0.9339 - val_loss: 0.0545 - val_dice_coef: 0.8828
# Epoch 36/40
# 207/207 [==============================] - 11s 52ms/step - loss: 0.0267 - dice_coef: 0.9345 - val_loss: 0.0538 - val_dice_coef: 0.8810
# Epoch 37/40
# 207/207 [==============================] - 11s 53ms/step - loss: 0.0261 - dice_coef: 0.9358 - val_loss: 0.0552 - val_dice_coef: 0.8839
# Epoch 38/40
# 207/207 [==============================] - 11s 54ms/step - loss: 0.0257 - dice_coef: 0.9370 - val_loss: 0.0580 - val_dice_coef: 0.8822
# Epoch 39/40
# 207/207 [==============================] - 11s 53ms/step - loss: 0.0254 - dice_coef: 0.9374 - val_loss: 0.0543 - val_dice_coef: 0.8870
# Epoch 40/40
# 207/207 [==============================] - 11s 53ms/step - loss: 0.0251 - dice_coef: 0.9385 - val_loss: 0.0537 - val_dice_coef: 0.8880

# %%
fig, axs = plt.subplots(1,2, figsize = (12,5), dpi = 130)

axs[0].grid(linestyle="dashdot")
axs[0].set_title("Dice Coefficients")
axs[0].plot(hist.history['dice_coef'])
axs[0].plot(hist.history['val_dice_coef'])
axs[0].legend(["train", "validation"])

axs[1].grid(linestyle="dashdot")
axs[1].set_title("Loss")
axs[1].plot(hist.history['loss'])
axs[1].plot(hist.history['val_loss'])
axs[1].legend(["train", "validation"])

# %%
  # Visual the model

  visualkeras.layered_view(model, legend = True, spacing = 50, min_z = 80, min_xy = 20)
# Out:
# <PIL.Image.Image image mode=RGBA size=6493x719>

# %%
# Prediction

pred = model.predict(X_test, verbose=1)

threshold  = pred.mean() + pred.std()
bitmap_preds = (pred > threshold).astype(np.uint8)
# Out:
# 45/45 [==============================] - 1s 14ms/step

# %%
# Test samples and their prediction masks

create_random_image_and_mask(X_test,bitmap_preds, cmap2 = None)
create_random_image_and_mask(X_test,bitmap_preds, cmap2 = None)
create_random_image_and_mask(X_test,bitmap_preds, cmap2 = None)
