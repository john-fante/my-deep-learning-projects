# %% [markdown]
# I tried a custom CNN model and other pretrained models (Xception,ResNet50, MobileNet, EfficientNetB0, ResNet101). However, I haven't obtained sufficient results in respect of accuracy and F1 score. This dataset is unbalanced. For example, the Cavity class has only 22 samples in the test set. I tried the 'class weights' method, but there was no improvement. I used a basic data augmentation method.
#
#
# I have used the following methods.
#
# * The project took place using <b>Google TPU</b>,
# * Used <b>tf.data</b> for input pipeline,
# * I used several image processing methods for images <b>(Contrast Limited AHE (CLAHE)</b>[1])
# * I used a pretrained <b>DenseNet201</b> architecture for the feature extraction stage,
# * <b>elu</b> activation function during the classification stage,
#
#
# ## Image Processing Operation
# ![Screenshot 2023-10-16 at 7.05.49 PM.png](attachment:2d5e861e-98c7-455f-93c6-badfb90b292f.png)
#
# ## Test Set Predictions
# ![Screenshot 2023-10-16 at 7.22.21 PM.png](attachment:82a5a858-ca00-4f52-8335-6a994653d5a5.png)
# ![Screenshot 2023-10-16 at 7.21.56 PM.png](attachment:15174be9-0f66-4703-ab29-e7b9e6ca1f79.png)
#
# ## My Another Projects
# * [(76 GB) 160 Polish Bird Sounds Classification](https://www.kaggle.com/code/banddaniel/76-gb-160-polish-bird-sounds-classification)
# * [Segment Medical Instrument, w/Custom DeepLabv3+(Dice: 0.86)](https://www.kaggle.com/code/banddaniel/segment-medical-instrument-deeplabv3-dice-0-86)
# * [Rice Classification w/Custom ResNet50 (ACC 85%)](https://www.kaggle.com/code/banddaniel/rice-classification-w-custom-resnet50-acc-85)
# * [Lung Segmentation UNet w/SeparableConv (Dice:0.93)](https://www.kaggle.com/code/banddaniel/lung-segmentation-unet-w-separableconv-dice-0-93)
# * [Plate Detection w/detectron2 (mAP@75: 89.19)](https://www.kaggle.com/code/banddaniel/plate-detection-w-detectron2-map-75-89-19)
#
#
# ## References
# 1. https://en.wikipedia.org/wiki/Adaptive_histogram_equalization

# %%
# Importing dependencies

import os
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

import tensorflow as tf
from tensorflow.keras.applications import Xception,ResNet50, DenseNet201,MobileNet, EfficientNetB0, ResNet101
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer, Input, Conv2D, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, MaxPooling2D, Add, AveragePooling2D, Flatten,Dense
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

from tensorflow.keras.layers import Layer,Input, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Flatten
from tensorflow.keras.layers import Dense, Dropout, Activation, BatchNormalization, SeparableConv2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau


SEED = 10
IMG_SIZE = 256, 256
BATCH_SIZE = 64
# Out:
# D1016 16:49:01.806575018      14 config.cc:119]                        gRPC EXPERIMENT tcp_frame_size_tuning               OFF (default:OFF)
# D1016 16:49:01.806604951      14 config.cc:119]                        gRPC EXPERIMENT tcp_rcv_lowat                       OFF (default:OFF)
# D1016 16:49:01.806608309      14 config.cc:119]                        gRPC EXPERIMENT peer_state_based_framing            OFF (default:OFF)
# D1016 16:49:01.806610913      14 config.cc:119]                        gRPC EXPERIMENT flow_control_fixes                  ON  (default:ON)
# D1016 16:49:01.806613183      14 config.cc:119]                        gRPC EXPERIMENT memory_pressure_controller          OFF (default:OFF)
# D1016 16:49:01.806615751      14 config.cc:119]                        gRPC EXPERIMENT unconstrained_max_quota_buffer_size OFF (default:OFF)
# D1016 16:49:01.806618933      14 config.cc:119]                        gRPC EXPERIMENT new_hpack_huffman_decoder           ON  (default:ON)
# D1016 16:49:01.806621236      14 config.cc:119]                        gRPC EXPERIMENT event_engine_client                 OFF (default:OFF)
# D1016 16:49:01.806623511      14 config.cc:119]                        gRPC EXPERIMENT monitoring_experiment               ON  (default:ON)
# D1016 16:49:01.806625763      14 config.cc:119]                        gRPC EXPERIMENT promise_based_client_call           OFF (default:OFF)
# D1016 16:49:01.806628091      14 config.cc:119]                        gRPC EXPERIMENT free_large_allocator                OFF (default:OFF)
# D1016 16:49:01.806630293      14 config.cc:119]                        gRPC EXPERIMENT promise_based_server_call           OFF (default:OFF)
# D1016 16:49:01.806632712      14 config.cc:119]                        gRPC EXPERIMENT transport_supplies_client_latency   OFF (default:OFF)
# D1016 16:49:01.806635078      14 config.cc:119]                        gRPC EXPERIMENT event_engine_listener               OFF (default:OFF)
# I1016 16:49:01.806926413      14 ev_epoll1_linux.cc:122]               grpc epoll fd: 58
# D1016 16:49:01.806939341      14 ev_posix.cc:144]                      Using polling engine: epoll1
# D1016 16:49:01.807011499      14 dns_resolver_ares.cc:822]             Using ares dns resolver
# D1016 16:49:01.807492725      14 lb_policy_registry.cc:46]             registering LB policy factory for "priority_experimental"
# D1016 16:49:01.807507871      14 lb_policy_registry.cc:46]             registering LB policy factory for "outlier_detection_experimental"
# D1016 16:49:01.807511908      14 lb_policy_registry.cc:46]             registering LB policy factory for "weighted_target_experimental"
# D1016 16:49:01.807515382      14 lb_policy_registry.cc:46]             registering LB policy factory for "pick_first"
# D1016 16:49:01.807518948      14 lb_policy_registry.cc:46]             registering LB policy factory for "round_robin"
# D1016 16:49:01.807522566      14 lb_policy_registry.cc:46]             registering LB policy factory for "weighted_round_robin_experimental"
# D1016 16:49:01.807531264      14 lb_policy_registry.cc:46]             registering LB policy factory for "ring_hash_experimental"
# D1016 16:49:01.807554608      14 lb_policy_registry.cc:46]             registering LB policy factory for "grpclb"
# D1016 16:49:01.807590716      14 lb_policy_registry.cc:46]             registering LB policy factory for "rls_experimental"
# D1016 16:49:01.807610322      14 lb_policy_registry.cc:46]             registering LB policy factory for "xds_cluster_manager_experimental"
# D1016 16:49:01.807614384      14 lb_policy_registry.cc:46]             registering LB policy factory for "xds_cluster_impl_experimental"
# D1016 16:49:01.807618585      14 lb_policy_registry.cc:46]             registering LB policy factory for "cds_experimental"
# D1016 16:49:01.807627110      14 lb_policy_registry.cc:46]             registering LB policy factory for "xds_cluster_resolver_experimental"
# D1016 16:49:01.807630982      14 lb_policy_registry.cc:46]             registering LB policy factory for "xds_override_host_experimental"
# D1016 16:49:01.807634663      14 lb_policy_registry.cc:46]             registering LB policy factory for "xds_wrr_locality_experimental"
# D1016 16:49:01.807639822      14 certificate_provider_registry.cc:35]  registering certificate provider factory for "file_watcher"
# I1016 16:49:01.811734691      14 socket_utils_common_posix.cc:408]     Disabling AF_INET6 sockets because ::1 is not available.
# I1016 16:49:01.828234320     172 socket_utils_common_posix.cc:337]     TCP_USER_TIMEOUT is available. TCP_USER_TIMEOUT will be used thereafter
# E1016 16:49:01.833988800     172 oauth2_credentials.cc:236]            oauth_fetch: UNKNOWN:C-ares status is not ARES_SUCCESS qtype=A name=metadata.google.internal. is_balancer=0: Domain name not found {created_time:"2023-10-16T16:49:01.833970329+00:00", grpc_status:2}

# %%
# Connecting TPU and creating strategy and the model

tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
strategy = tf.distribute.TPUStrategy(tpu)
# Out:
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Initializing the TPU system: local
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)

# %% [markdown]
# # <span style="color:#e74c3c;"> Preprocessing </span>

# %%
# chosing a random image from the train dataset
original_train_images =  sorted(os.listdir('/kaggle/input/dental-radiography/train'))
org_img_path =  np.random.permutation(original_train_images)[0]
img = cv2.imread(os.path.join('/kaggle/input/dental-radiography/train',org_img_path))[:,::,1]


# A basic segmentation of the image from the background
# In this stage I wanted to reduce the white pixel number 
img2 = img - 255
kernel = np.ones((2,2))
kernel2 = np.ones((3,3))
dilated_mask = cv2.dilate(img2, kernel, iterations = 3)
ret, thresh = cv2.threshold(dilated_mask, 0, 255, cv2.THRESH_BINARY) 
dilated_mask2 = cv2.dilate(thresh, kernel2, iterations = 3)
img = img / 255.0
res_img = dilated_mask2*img
res_img = np.uint8(res_img)

# CLAHE operation
clahe_op = cv2.createCLAHE(clipLimit= 20)
final_img = clahe_op.apply(res_img)
    
fig, axs = plt.subplots(1,2, dpi = 200)

axs[0].imshow(img,  cmap = 'gray')
axs[0].axis('off')
axs[0].set_title('an original image', fontsize = 7)

axs[1].imshow(final_img,  cmap = 'gray')
axs[1].axis('off')
axs[1].set_title('after image processing operations', fontsize = 7, color = 'red')
# Out:
# Text(0.5, 1.0, 'after image processing operations')

# %%
# Creating new directories
os.mkdir(os.path.join('/kaggle/working/', 'train'))
os.mkdir(os.path.join('/kaggle/working/', 'valid'))
os.mkdir(os.path.join('/kaggle/working/', 'test'))

# %%
# Image processing function
# reading -> background segmentation -> adaptive histogram equalization (CLAHE)

def new_img(main_path, target_path):
    main_imgs = sorted(os.listdir(main_path))
    for i in main_imgs :
        try:
            img = cv2.imread(os.path.join(main_path, i))[:,::,1]
            img2 = img - 255
            kernel = np.ones((2,2))
            kernel2 = np.ones((3,3))
            
            dilated_mask = cv2.dilate(img2, kernel, iterations = 3)
            ret, thresh = cv2.threshold(dilated_mask, 0, 255, cv2.THRESH_BINARY) 
            dilated_mask2 = cv2.dilate(thresh, kernel2, iterations = 3)
            img = img / 255.0
            res_img = dilated_mask2*img
            
            res_img = np.uint8(res_img)

            clahe_op = cv2.createCLAHE(clipLimit= 20) # CLAHE function
            final_img = clahe_op.apply(res_img)
            
            
            cv2.imwrite(os.path.join(target_path, i), final_img)
        except TypeError:
            pass

# %%
# Applying the image processing function to all images
new_img('/kaggle/input/dental-radiography/train', '/kaggle/working/train')
new_img('/kaggle/input/dental-radiography/valid', '/kaggle/working/valid')
new_img('/kaggle/input/dental-radiography/test', '/kaggle/working/test')

# %%
train_data = pd.read_csv('/kaggle/input/dental-radiography/train/_annotations.csv')
validation_data = pd.read_csv('/kaggle/input/dental-radiography/valid/_annotations.csv')
test_data = pd.read_csv('/kaggle/input/dental-radiography/test/_annotations.csv')

# look-up table
classes = {0: 'Fillings', 1: 'Implant', 2: 'Impacted Tooth', 3: 'Cavity'}

def create_classes(X):
    if X == 'Fillings':
        return 0
    elif X == 'Implant':
        return 1
    elif X == 'Impacted Tooth':
        return 2
    elif X == 'Cavity':
        return 3
    else:
        print('MISSING')
    
    
train_data['encoded_class'] = train_data['class'].apply(create_classes)
validation_data['encoded_class'] = validation_data['class'].apply(create_classes)
test_data['encoded_class'] = test_data['class'].apply(create_classes)


train_data['full_path'] = '/kaggle/working/train/' + train_data['filename']
validation_data['full_path'] = '/kaggle/working/valid/' + validation_data['filename']
test_data['full_path'] = '/kaggle/working/test/' + test_data['filename']


print("train images: ", train_data.shape[0])
print("validation images: ", validation_data.shape[0])
print("test images: ", test_data.shape[0])
# Out:
# train images:  8030
# validation images:  780
# test images:  473

# %% [markdown]
# # <span style="color:#e74c3c;"> Creating </span> tf.data Pipeline

# %%
# Reading and resizing images
def img_preprocessing(image, label):
    img = tf.io.read_file(image)
    img = tf.io.decode_jpeg(img, channels = 3)
    img = tf.image.resize(img, size =  (IMG_SIZE) )
    img = tf.cast(img, tf.float32) / 255.0

    return img, label


# Basic data augmentation - randomly flips left or right
def img_augmentation(image, label):

    radn_num = np.random.randint(0, 100)
    if radn_num % 2 == 0:
        img = tf.image.random_flip_left_right(image)
        return img, label
    else:
        return image, label

# %%
# Creating dataset loaders and tf.datasets

train_loader = tf.data.Dataset.from_tensor_slices((train_data['full_path'], train_data['encoded_class'] ))
train_dataset = (train_loader
                 .map(img_preprocessing, num_parallel_calls=tf.data.AUTOTUNE)
                 .map(img_augmentation, num_parallel_calls=tf.data.AUTOTUNE)
                 .shuffle(train_data.shape[0])
                 .batch(BATCH_SIZE)
                 .prefetch(tf.data.AUTOTUNE))


valid_loader = tf.data.Dataset.from_tensor_slices((validation_data['full_path'], validation_data['encoded_class'] ))
valid_dataset = (valid_loader
                 .map(img_preprocessing, num_parallel_calls=tf.data.AUTOTUNE)
                 .batch(BATCH_SIZE)
                 .prefetch(tf.data.AUTOTUNE))


test_loader = tf.data.Dataset.from_tensor_slices((test_data['full_path'], test_data['encoded_class'] ))
test_dataset = (test_loader
                 .map(img_preprocessing, num_parallel_calls=tf.data.AUTOTUNE)
                .batch(BATCH_SIZE)
                .prefetch(tf.data.AUTOTUNE))

# %% [markdown]
# # <span style="color:#e74c3c;"> DenseNet201 </span> Model

# %%
with strategy.scope():
    pretrained_model = DenseNet201(weights='imagenet',include_top=False ,input_shape=[*IMG_SIZE, 3])
    pretrained_model.trainable = True

    inp = Input(shape = (*IMG_SIZE, 3))
    densenet = pretrained_model(inp)
    
    X = GlobalAveragePooling2D()(densenet)
    X = Dense(256, activation = 'elu')(X)
    X = Dropout(0.3)(X)
    
    X = Dense(128, activation = 'elu')(X)
    X = Dropout(0.2)(X)
    
    X = Dense(32, activation = 'elu')(X)
    
    out = Dense(4, activation = 'softmax')(X)
    
    model = Model(inputs = inp, outputs = out)
    
    my_callbacks = [EarlyStopping(min_delta = 0.0001, monitor = 'loss', patience = 40 ),
                   ReduceLROnPlateau( monitor="val_loss", factor=0.1, patience=15)]

    
model.compile(optimizer  = tf.keras.optimizers.Adam(), loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 1s 0us/step

# %% [markdown]
# # <span style="color:#e74c3c;"> Training</span>

# %%
hist = model.fit(train_dataset, epochs = 60, validation_data = valid_dataset, callbacks = my_callbacks)
# Out:
# Epoch 1/60
# 2023-10-16 16:51:48.464399: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignAddVariableOp.
# 2023-10-16 16:51:51.160486: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignAddVariableOp.
# 126/126 [==============================] - ETA: 0s - loss: 0.9720 - accuracy: 0.6364
# 2023-10-16 16:55:50.918413: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignAddVariableOp.
# 2023-10-16 16:55:51.437541: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignAddVariableOp.
# 126/126 [==============================] - 355s 1s/step - loss: 0.9720 - accuracy: 0.6364 - val_loss: 1.5293 - val_accuracy: 0.6923 - lr: 0.0010
# Epoch 2/60
# 126/126 [==============================] - 22s 170ms/step - loss: 0.8105 - accuracy: 0.6709 - val_loss: 3.0132 - val_accuracy: 0.6923 - lr: 0.0010
# Epoch 3/60
# 126/126 [==============================] - 23s 172ms/step - loss: 0.7599 - accuracy: 0.6932 - val_loss: 1.1303 - val_accuracy: 0.5321 - lr: 0.0010
# Epoch 4/60
# 126/126 [==============================] - 22s 170ms/step - loss: 0.7234 - accuracy: 0.7172 - val_loss: 1.4849 - val_accuracy: 0.2051 - lr: 0.0010
# Epoch 5/60
# 126/126 [==============================] - 22s 167ms/step - loss: 0.7068 - accuracy: 0.7219 - val_loss: 0.8667 - val_accuracy: 0.6397 - lr: 0.0010
# Epoch 6/60
# 126/126 [==============================] - 22s 168ms/step - loss: 0.6856 - accuracy: 0.7212 - val_loss: 2.9080 - val_accuracy: 0.2038 - lr: 0.0010
# Epoch 7/60
# 126/126 [==============================] - 22s 168ms/step - loss: 0.6756 - accuracy: 0.7232 - val_loss: 1.0718 - val_accuracy: 0.7026 - lr: 0.0010
# Epoch 8/60
# 126/126 [==============================] - 22s 168ms/step - loss: 0.6657 - accuracy: 0.7289 - val_loss: 1.5090 - val_accuracy: 0.3385 - lr: 0.0010
# Epoch 9/60
# 126/126 [==============================] - 22s 167ms/step - loss: 0.6528 - accuracy: 0.7283 - val_loss: 0.9788 - val_accuracy: 0.6628 - lr: 0.0010
# Epoch 10/60
# 126/126 [==============================] - 22s 168ms/step - loss: 0.6401 - accuracy: 0.7334 - val_loss: 0.8213 - val_accuracy: 0.7282 - lr: 0.0010
# Epoch 11/60
# 126/126 [==============================] - 21s 166ms/step - loss: 0.6329 - accuracy: 0.7361 - val_loss: 0.8387 - val_accuracy: 0.6628 - lr: 0.0010
# Epoch 12/60
# 126/126 [==============================] - 22s 169ms/step - loss: 0.6333 - accuracy: 0.7347 - val_loss: 0.9054 - val_accuracy: 0.7269 - lr: 0.0010
# Epoch 13/60
# 126/126 [==============================] - 22s 167ms/step - loss: 0.6253 - accuracy: 0.7347 - val_loss: 0.8329 - val_accuracy: 0.7256 - lr: 0.0010
# Epoch 14/60
# 126/126 [==============================] - 22s 169ms/step - loss: 0.6120 - accuracy: 0.7360 - val_loss: 0.8941 - val_accuracy: 0.6385 - lr: 0.0010
# Epoch 15/60
# 126/126 [==============================] - 23s 175ms/step - loss: 0.6134 - accuracy: 0.7359 - val_loss: 0.8422 - val_accuracy: 0.6051 - lr: 0.0010
# Epoch 16/60
# 126/126 [==============================] - 22s 169ms/step - loss: 0.6046 - accuracy: 0.7453 - val_loss: 1.9585 - val_accuracy: 0.4769 - lr: 0.0010
# Epoch 17/60
# 126/126 [==============================] - 22s 168ms/step - loss: 0.6030 - accuracy: 0.7382 - val_loss: 0.9787 - val_accuracy: 0.5962 - lr: 0.0010
# Epoch 18/60
# 126/126 [==============================] - 22s 170ms/step - loss: 0.5990 - accuracy: 0.7400 - val_loss: 0.8770 - val_accuracy: 0.6231 - lr: 0.0010
# Epoch 19/60
# 126/126 [==============================] - 22s 171ms/step - loss: 0.6005 - accuracy: 0.7435 - val_loss: 1.0183 - val_accuracy: 0.6359 - lr: 0.0010
# Epoch 20/60
# 126/126 [==============================] - 22s 169ms/step - loss: 0.5860 - accuracy: 0.7441 - val_loss: 1.0012 - val_accuracy: 0.7013 - lr: 0.0010
# Epoch 21/60
# 126/126 [==============================] - 21s 167ms/step - loss: 0.5859 - accuracy: 0.7396 - val_loss: 0.7979 - val_accuracy: 0.6551 - lr: 0.0010
# Epoch 22/60
# 126/126 [==============================] - 22s 168ms/step - loss: 0.5843 - accuracy: 0.7432 - val_loss: 0.9805 - val_accuracy: 0.6500 - lr: 0.0010
# Epoch 23/60
# 126/126 [==============================] - 22s 167ms/step - loss: 0.5874 - accuracy: 0.7467 - val_loss: 0.9728 - val_accuracy: 0.6013 - lr: 0.0010
# Epoch 24/60
# 126/126 [==============================] - 22s 167ms/step - loss: 0.5731 - accuracy: 0.7473 - val_loss: 1.2840 - val_accuracy: 0.5474 - lr: 0.0010
# Epoch 25/60
# 126/126 [==============================] - 21s 165ms/step - loss: 0.5745 - accuracy: 0.7468 - val_loss: 0.8776 - val_accuracy: 0.7462 - lr: 0.0010
# Epoch 26/60
# 126/126 [==============================] - 22s 170ms/step - loss: 0.5785 - accuracy: 0.7433 - val_loss: 0.9517 - val_accuracy: 0.6462 - lr: 0.0010
# Epoch 27/60
# 126/126 [==============================] - 22s 168ms/step - loss: 0.5779 - accuracy: 0.7440 - val_loss: 0.7023 - val_accuracy: 0.7449 - lr: 0.0010
# Epoch 28/60
# 126/126 [==============================] - 22s 167ms/step - loss: 0.5626 - accuracy: 0.7466 - val_loss: 1.5041 - val_accuracy: 0.7051 - lr: 0.0010
# Epoch 29/60
# 126/126 [==============================] - 22s 166ms/step - loss: 0.5639 - accuracy: 0.7501 - val_loss: 1.0241 - val_accuracy: 0.6731 - lr: 0.0010
# Epoch 30/60
# 126/126 [==============================] - 21s 166ms/step - loss: 0.5643 - accuracy: 0.7468 - val_loss: 1.7990 - val_accuracy: 0.6090 - lr: 0.0010
# Epoch 31/60
# 126/126 [==============================] - 22s 168ms/step - loss: 0.5702 - accuracy: 0.7483 - val_loss: 1.1216 - val_accuracy: 0.5551 - lr: 0.0010
# Epoch 32/60
# 126/126 [==============================] - 21s 166ms/step - loss: 0.5606 - accuracy: 0.7517 - val_loss: 0.8795 - val_accuracy: 0.7423 - lr: 0.0010
# Epoch 33/60
# 126/126 [==============================] - 22s 167ms/step - loss: 0.5574 - accuracy: 0.7514 - val_loss: 1.0236 - val_accuracy: 0.7231 - lr: 0.0010
# Epoch 34/60
# 126/126 [==============================] - 23s 178ms/step - loss: 0.5570 - accuracy: 0.7486 - val_loss: 1.0154 - val_accuracy: 0.5782 - lr: 0.0010
# Epoch 35/60
# 126/126 [==============================] - 22s 170ms/step - loss: 0.5589 - accuracy: 0.7502 - val_loss: 1.0091 - val_accuracy: 0.5449 - lr: 0.0010
# Epoch 36/60
# 126/126 [==============================] - 22s 170ms/step - loss: 0.5570 - accuracy: 0.7499 - val_loss: 0.8621 - val_accuracy: 0.7269 - lr: 0.0010
# Epoch 37/60
# 126/126 [==============================] - 22s 171ms/step - loss: 0.5501 - accuracy: 0.7524 - val_loss: 0.7980 - val_accuracy: 0.7423 - lr: 0.0010
# Epoch 38/60
# 126/126 [==============================] - 22s 168ms/step - loss: 0.5467 - accuracy: 0.7527 - val_loss: 1.4003 - val_accuracy: 0.6782 - lr: 0.0010
# Epoch 39/60
# 126/126 [==============================] - 22s 169ms/step - loss: 0.5509 - accuracy: 0.7545 - val_loss: 0.9147 - val_accuracy: 0.6218 - lr: 0.0010
# Epoch 40/60
# 126/126 [==============================] - 22s 166ms/step - loss: 0.5485 - accuracy: 0.7529 - val_loss: 0.8211 - val_accuracy: 0.7244 - lr: 0.0010
# Epoch 41/60
# 126/126 [==============================] - 22s 167ms/step - loss: 0.5502 - accuracy: 0.7498 - val_loss: 1.1436 - val_accuracy: 0.7231 - lr: 0.0010
# Epoch 42/60
# 126/126 [==============================] - 22s 169ms/step - loss: 0.5444 - accuracy: 0.7542 - val_loss: 1.0321 - val_accuracy: 0.7282 - lr: 0.0010
# Epoch 43/60
# 126/126 [==============================] - 22s 168ms/step - loss: 0.5189 - accuracy: 0.7616 - val_loss: 0.8765 - val_accuracy: 0.7269 - lr: 1.0000e-04
# Epoch 44/60
# 126/126 [==============================] - 21s 166ms/step - loss: 0.5148 - accuracy: 0.7635 - val_loss: 0.8254 - val_accuracy: 0.7346 - lr: 1.0000e-04
# Epoch 45/60
# 126/126 [==============================] - 21s 165ms/step - loss: 0.5100 - accuracy: 0.7639 - val_loss: 0.8511 - val_accuracy: 0.7295 - lr: 1.0000e-04
# Epoch 46/60
# 126/126 [==============================] - 22s 168ms/step - loss: 0.5079 - accuracy: 0.7630 - val_loss: 0.8365 - val_accuracy: 0.7449 - lr: 1.0000e-04
# Epoch 47/60
# 126/126 [==============================] - 22s 167ms/step - loss: 0.5084 - accuracy: 0.7648 - val_loss: 0.8365 - val_accuracy: 0.7474 - lr: 1.0000e-04
# Epoch 48/60
# 126/126 [==============================] - 22s 166ms/step - loss: 0.5058 - accuracy: 0.7633 - val_loss: 0.8266 - val_accuracy: 0.7385 - lr: 1.0000e-04
# Epoch 49/60
# 126/126 [==============================] - 22s 170ms/step - loss: 0.5089 - accuracy: 0.7631 - val_loss: 0.8678 - val_accuracy: 0.7410 - lr: 1.0000e-04
# Epoch 50/60
# 126/126 [==============================] - 22s 167ms/step - loss: 0.5062 - accuracy: 0.7654 - val_loss: 0.8475 - val_accuracy: 0.7308 - lr: 1.0000e-04
# Epoch 51/60
# 126/126 [==============================] - 21s 167ms/step - loss: 0.5042 - accuracy: 0.7625 - val_loss: 0.8572 - val_accuracy: 0.7244 - lr: 1.0000e-04
# Epoch 52/60
# 126/126 [==============================] - 22s 166ms/step - loss: 0.5026 - accuracy: 0.7655 - val_loss: 0.8599 - val_accuracy: 0.7423 - lr: 1.0000e-04
# Epoch 53/60
# 126/126 [==============================] - 23s 182ms/step - loss: 0.5056 - accuracy: 0.7658 - val_loss: 0.8839 - val_accuracy: 0.7269 - lr: 1.0000e-04
# Epoch 54/60
# 126/126 [==============================] - 22s 171ms/step - loss: 0.5020 - accuracy: 0.7650 - val_loss: 0.8794 - val_accuracy: 0.7436 - lr: 1.0000e-04
# Epoch 55/60
# 126/126 [==============================] - 22s 173ms/step - loss: 0.5027 - accuracy: 0.7648 - val_loss: 0.8584 - val_accuracy: 0.7436 - lr: 1.0000e-04
# Epoch 56/60
# 126/126 [==============================] - 23s 175ms/step - loss: 0.5005 - accuracy: 0.7666 - val_loss: 0.8745 - val_accuracy: 0.7436 - lr: 1.0000e-04
# Epoch 57/60
# 126/126 [==============================] - 22s 168ms/step - loss: 0.5029 - accuracy: 0.7682 - val_loss: 0.8564 - val_accuracy: 0.7282 - lr: 1.0000e-04
# Epoch 58/60
# 126/126 [==============================] - 22s 168ms/step - loss: 0.4998 - accuracy: 0.7656 - val_loss: 0.8556 - val_accuracy: 0.7385 - lr: 1.0000e-05
# Epoch 59/60
# 126/126 [==============================] - 22s 167ms/step - loss: 0.5014 - accuracy: 0.7670 - val_loss: 0.8522 - val_accuracy: 0.7372 - lr: 1.0000e-05
# Epoch 60/60
# 126/126 [==============================] - 22s 167ms/step - loss: 0.4962 - accuracy: 0.7677 - val_loss: 0.8587 - val_accuracy: 0.7321 - lr: 1.0000e-05

# %% [markdown]
# # <span style="color:#e74c3c;"> Training</span> Results

# %%
fig, axs = plt.subplots(1,2, figsize = (10, 4), dpi = 100)

axs[0].grid(linestyle = 'dashdot')
axs[0].plot(hist.history['loss'])
axs[0].plot(hist.history['val_loss'])
axs[0].set_xlabel('epochs', fontsize = 10)
axs[0].legend(['train loss', 'validation loss'], fontsize = 10)


axs[1].grid(linestyle = 'dashdot')
axs[1].plot(hist.history['accuracy'])
axs[1].plot(hist.history['val_accuracy'])
axs[1].set_xlabel('epochs', fontsize = 10)
axs[1].legend(['train accuracy', 'validation accuracy'], fontsize = 10)

# %% [markdown]
# # <span style="color:#e74c3c;"> Test </span> Prediction, Evaluation

# %%
with strategy.scope():
    test_eval = model.evaluate(test_dataset)
    print('Test Loss: {0:.3f}'.format(test_eval[0]))
    print('Test Accuracy: {0:.3f} %'.format(test_eval[1]*100))
# Out:
# 8/8 [==============================] - 26s 4s/step - loss: 0.7708 - accuracy: 0.7463
# Test Loss: 0.771
# Test Accuracy: 74.630 %

# %%
test_take1 =  test_dataset.take(-1)
test_take1_ = list(test_take1)
pred = model.predict(test_take1)
pred = np.argmax(pred, axis = 1)
# Out:
# 2023-10-16 17:19:16.237877: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignAddVariableOp.
# 2023-10-16 17:19:16.770081: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignAddVariableOp.
# 8/8 [==============================] - 50s 3s/step

# %% [markdown]
# # <span style="color:#e74c3c;"> Classification </span> Report

# %%
clf = classification_report(test_data['encoded_class'], pred, target_names = list(classes.values()))
print(clf)
# Out:
#                 precision    recall  f1-score   support
#
#       Fillings       0.77      0.92      0.84       315
#        Implant       0.70      0.30      0.42       104
# Impacted Tooth       0.68      0.88      0.77        32
#         Cavity       0.33      0.23      0.27        22
#
#       accuracy                           0.75       473
#      macro avg       0.62      0.58      0.57       473
#   weighted avg       0.73      0.75      0.72       473

# %% [markdown]
# # <span style="color:#e74c3c;"> Confusion </span> Matrix

# %%
cm = confusion_matrix(test_data['encoded_class'], pred)
cmd = ConfusionMatrixDisplay(cm, display_labels = list(classes.values()))

fig, ax = plt.subplots(figsize=(6,6))
cmd.plot(ax=ax,  cmap = 'Purples', colorbar = False)

# %% [markdown]
# # <span style="color:#e74c3c;"> Test Set </span> Predictions

# %%
# A function that creating 5 random images in the test set and predictions

# Red title -> a false prediction
# Green title -> a true prediction

def random_test_sample_with_prediction():
    idxs = np.random.permutation(len(pred))[:5]
    batch_idx = idxs // BATCH_SIZE
    image_idx = idxs-batch_idx * BATCH_SIZE
    idx = idxs

    fig, axs = plt.subplots(1,5, figsize = (12,12) ,dpi = 150)

    for i in range(5):
        img = test_take1_[batch_idx[i]][0][image_idx[i]]
        label = test_take1_[batch_idx[i]][1][image_idx[i]].numpy()
        

        if int(pred[idx[i]]) == label:
            axs[i].imshow(img , cmap = 'gray') 
            axs[i].axis('off')
            axs[i].set_title('image (no: ' + str(idx[i])  + ')' + '\n' + classes[label], fontsize = 8, color = 'green')
        else:
            axs[i].imshow(img , cmap = 'gray')
            axs[i].axis('off')
            axs[i].set_title('image (no: ' + str(idx[i])  + ')' + '\n' + classes[label], fontsize = 8, color = 'red')

# %%
# Red title -> a false prediction
# Green title -> a true prediction

random_test_sample_with_prediction()
random_test_sample_with_prediction()
random_test_sample_with_prediction()
random_test_sample_with_prediction()
